# %% [markdown]
# <a href="https://colab.research.google.com/github/rishithatirkala-byte/RishithaTirkala-ai-2025-2026-Even-AI-DS-4067/blob/main/nrml_vs_skewed_distn_24_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Comparison of Normal and Skewed Distributions”

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate datasets
normal_data = np.random.normal(loc=70, scale=5, size=1000)

# Right-skewed distribution (Exponential)
right_skewed = np.random.exponential(scale=2, size=1000)

# Left-skewed distribution (negative exponential)
left_skewed = -np.random.exponential(scale=2, size=1000)

# ---- Plot Normal Distribution ----
plt.hist(normal_data, bins=30)
plt.title("Normal Distribution")
plt.show()

# ---- Plot Right Skewed Distribution ----
plt.hist(right_skewed, bins=30)
plt.title("Right Skewed Distribution")
plt.show()

# ---- Plot Left Skewed Distribution ----
plt.hist(left_skewed, bins=30)
plt.title("Left Skewed Distribution")
plt.show()

# ---- Mean and Median ----
print("Normal Data Mean:", np.mean(normal_data))
print("Normal Data Median:", np.median(normal_data))

print("Right Skewed Mean:", np.mean(right_skewed))
print("Right Skewed Median:", np.median(right_skewed))

print("Left Skewed Mean:", np.mean(left_skewed))
print("Left Skewed Median:", np.median(left_skewed))
# Out:
# Normal Data Mean: 69.61904352225066
# Normal Data Median: 69.65557240934521
# Right Skewed Mean: 2.0565605214204288
# Right Skewed Median: 1.4335676288609664
# Left Skewed Mean: -1.9126212052637606
# Left Skewed Median: -1.3128766536811802
