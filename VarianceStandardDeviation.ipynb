# %% [markdown]
# <a href="https://colab.research.google.com/github/rishithatirkala-byte/RishithaTirkala-ai-2025-2026-Even-AI-DS-4067/blob/main/VarianceStandardDeviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create data
data = [10, 12, 15, 18, 20, 22, 25, 30, 35, 40]

# Create DataFrame
df = pd.DataFrame(data, columns=["Values"])

print("Dataset:")
print(df)

print("\nSummary Statistics:")
print(df.describe())

print("\nVariance:", np.var(data))
print("Standard Deviation:", np.std(data))

# Plot histogram
plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Data Distribution")
plt.show()

# Calculate mean and median
mean_value = np.mean(data)
median_value = np.median(data)

print("\nInference")
print("Mean Value:", mean_value)
print("Median Value:", median_value)
if mean_value > median_value:
    print("Data is slightly right-skewed")

elif mean_value < median_value:
    print("Data is slightly left-skewed")

else:
    print("Data is symmetric")
# Out:
# Dataset:
#    Values
# 0      10
# 1      12
# 2      15
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Summary Statistics:
#           Values
# count  10.000000
# mean   22.700000
# std     9.855061
# min    10.000000
# 25%    15.750000
# 50%    21.000000
# 75%    28.750000
# max    40.000000
#
# Variance: 87.41
# Standard Deviation: 9.34933152690608
# Inference
# Mean Value: 22.7
# Median Value: 21.0
# Data is slightly right-skewed
