# %% [markdown]
# <a href="https://colab.research.google.com/github/rishithatirkala-byte/RishithaTirkala-ai-2025-2026-Even-AI-DS-4067/blob/main/central_limit_10_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#central limit theorem
import numpy as np

# Population data
population = np.array([10,20,30,40,50,60,70])

# Population mean
mu = np.mean(population)
print("Population Mean:", mu)

# Population standard deviation
sigma = np.std(population)
print("Population Standard Deviation:", sigma)

# Number of samples
num_samples = 1000
sample_size = 3

sample_means = []

# Central Limit Theorem simulation
for i in range(num_samples):
    sample = np.random.choice(population, sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# Mean of sample means
mean_sample_means = np.mean(sample_means)

print("Mean of Sample Means:", mean_sample_means)
# Out:
# Population Mean: 40.0
# Population Standard Deviation: 20.0
# Mean of Sample Means: 39.79333333333333
